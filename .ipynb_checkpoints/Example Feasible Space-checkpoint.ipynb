# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(8, 5), dpi=200)
plt.figure(1)

x = np.array([2 , 3 , 11, 12])
y = np.array([12,6, 1, 15])
plt.scatter(x,y)

plt.plot(x[0:3], y[0:3],'o-')
plt.plot([x[0], x[3], x[2]], [y[0] ,y[3], y[2]], '--', color = 'black')
y1 = y
y2 = [y[0]]
m = (y[3] - y[0])/(x[3] - x[0])
b = (y[0]*x[3] - y[3]*x[0])/(x[3] - x[0])

y2.append(m*x[1]+b)
y2.append(m*x[2]+b)
y2.append(y[3])
print(y1)
print(y2)
plt.fill_between(x,y1,y2)
plt.legend(['Pareto Front'])

plt.title('An Example Feasible Space')
plt.show()
# Out:
# [12  6  1 15]
# [12, 12.3, 14.7, 15]
